# %%
import warnings
from numba import NumbaDeprecationWarning
# Silence the noise
warnings.simplefilter('ignore', category=NumbaDeprecationWarning)


# %run I6_instrumented.py
# Out:
# A COMPACT 6D TEST
# A =  (1^e16) + (1^e25) + (1^e34) + (1^e124) + (1^e135) + (1^e236) + (1^e123456)
# H = A * ~A =  -7 - (2^e1256) - (6^e1346) - (2^e2345)
# S1 = (H o 3) H =  -103 - (4^e1256) - (76^e1346) - (4^e2345)
# S0 = (S1 o 1) H =  -249 - (2^e1256) - (70^e1346) - (2^e2345)
# S = S0 o 1/3 =  83 - (2^e1256) - (70^e1346) - (2^e2345)
# D = S * H =  -153
# 1/H = S/D =  -0.54248 + (0.01307^e1256) + (0.45752^e1346) + (0.01307^e2345)
# H * 1/H =  1.0
# 1/A = ~A * 1/H =  (0.05882^e16) + (0.05882^e25) + (0.05882^e34) + (0.09804^e124) + (0.56863^e135) + (0.09804^e236) - (0.43137^e456) + (0.05882^e123456)
# A * 1/A =  1.0
